# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

import seaborn as sns
import matplotlib.pyplot as plt

import pickle

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment('nyc-taxi')
# Out:
# <Experiment: artifact_location='/home/azureuser/MLOps_zoomcamp/notebooks/mlruns/1', creation_time=1685564918529, experiment_id='1', last_update_time=1685564918529, lifecycle_stage='active', name='nyc-taxi', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])
    df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
    
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds()/60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    cat = ['PULocationID', 'DOLocationID']
    num = ['trip_distance']
    
    df[cat] = df[cat].astype(str)
    
    df['DO_PU'] = df['PULocationID'] + '_' + df['DOLocationID']
    
    return df

# %%
df_train = read_dataframe('data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('data/green_tripdata_2021-02.parquet')

# %%
df_train.shape, df_val.shape
# Out:
# ((73908, 22), (61921, 22))

# %%
df_train.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7         2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
#
#    RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0         1.0           43          151              1.0           1.01
# 1         1.0          166          239              1.0           2.53
# 2         1.0           41           42              1.0           1.12
# 3         1.0          168           75              1.0           1.99
# 7         1.0           75           75              6.0           0.45
#
#    fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# 0          5.5  ...        0.00           0.0       None
# 1         10.0  ...        2.81           0.0       None
# 2          6.0  ...        1.00           0.0       None
# 3          8.0  ...        0.00           0.0       None
# 7          3.5  ...        0.96           0.0       None
#
#    improvement_surcharge total_amount  payment_type  trip_type  \
# 0                    0.3         6.80           2.0        1.0
# 1                    0.3        16.86           1.0        1.0
# 2                    0.3         8.30           1.0        1.0
# 3                    0.3         9.30           2.0        1.0
# 7                    0.3         5.76           1.0        1.0
#
#    congestion_surcharge  duration    DO_PU
# 0                  0.00  3.933333   43_151
# 1                  2.75  8.750000  166_239
# 2                  0.00  5.966667    41_42
# 3                  0.00  7.083333   168_75
# 7                  0.00  2.316667    75_75
#
# [5 rows x 22 columns]

# %%
cat = ['DO_PU']
num = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[cat + num].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[cat + num].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'

y_train = df_train[target].values
y_val = df_val[target].values

# %%
with mlflow.start_run():

    # mlflow.set_tag("developer", "GT")
    mlflow.sklearn.autolog()

    mlflow.log_param("LinearRegression", "defaults")

    lr = LinearRegression()
    lr.fit(X_train, y_train)

    lr_pred = lr.predict(X_val)

    rmse = mean_squared_error(lr_pred, y_val, squared=False)
    mlflow.log_metric("rmse", rmse)
    print(rmse)

    mlflow.log_artifact(local_path="models/lr.bin", artifact_path="models_pickle")

# %%
with mlflow.start_run():

    # mlflow.set_tag("developer", "GT")
    mlflow.sklearn.autolog()
    
    alpha = 0.01
    mlflow.log_param("lasso", alpha)

    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, y_train)

    lasso_pred = lasso.predict(X_val)

    rmse = mean_squared_error(lasso_pred, y_val, squared=False)
    print(rmse)
    mlflow.log_metric("rmse", rmse)

    with open('models/lasso.bin', 'wb') as file:
        pickle.dump((dv, lasso), file)

    mlflow.log_artifact(local_path="models/lasso.bin", artifact_path="models_pickle")
# Out:
# 11.167275941179728

# %%
with mlflow.start_run():

    # mlflow.set_tag("developer", "GT")
    mlflow.sklearn.autolog()
    
    # alpha = 0.01
    # mlflow.log_param("lasso", alpha)

    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)

    rf_pred = rf.predict(X_val)

    rmse = mean_squared_error(rf_pred, y_val, squared=False)
    print(rmse)
    mlflow.log_metric("rmse", rmse)

    with open('models/rf.bin', 'wb') as file:
        pickle.dump((dv, rf), file)

    mlflow.log_artifact(local_path="models/rf.bin", artifact_path="models_pickle")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 10
#       6 # alpha = 0.01
#       7 # mlflow.log_param("lasso", alpha)
#       9 rf = RandomForestRegressor(n_estimators=100)
# ---> 10 rf.fit(X_train, y_train)
#      12 rf_pred = rf.predict(X_val)
#      14 rmse = mean_squared_error(rf_pred, y_val, squared=False)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:554, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     552     patch_function.call(call_original, *args, **kwargs)
#     553 else:
# --> 554     patch_function(call_original, *args, **kwargs)
#     556 session.state = "succeeded"
#     558 try_log_autologging_event(
#     559     AutologgingEventLogger.get_logger().log_patch_function_success,
#     560     session,
#    (...)
#     564     kwargs,
#     565 )
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:254, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     251     managed_run = create_managed_run()
#     253 try:
# --> 254     result = patch_function(original, *args, **kwargs)
#     255 except (Exception, KeyboardInterrupt):
#     256     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     257     # that runs are terminated if a user prematurely interrupts training execution
#     258     # (e.g. via sigint / ctrl-c)
#     259     if managed_run:
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/sklearn/__init__.py:1580, in _autolog.<locals>.patched_fit(fit_impl, allow_children_patch, original, self, *args, **kwargs)
#    1576 if t.should_log():
#    1577     # In `fit_mlflow` call, it will also call metric API for computing training metrics
#    1578     # so we need temporarily disable the post_training_metrics patching.
#    1579     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1580         result = fit_impl(original, self, *args, **kwargs)
#    1581     if should_log_post_training_metrics:
#    1582         _AUTOLOGGING_METRICS_MANAGER.register_model(
#    1583             self, mlflow.active_run().info.run_id
#    1584         )
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/sklearn/__init__.py:1368, in _autolog.<locals>.fit_mlflow(original, self, *args, **kwargs)
#    1366 _log_pretraining_metadata(autologging_client, self, *args, **kwargs)
#    1367 params_logging_future = autologging_client.flush(synchronous=False)
# -> 1368 fit_output = original(self, *args, **kwargs)
#    1369 _log_posttraining_metadata(autologging_client, self, X, y_true, sample_weight)
#    1370 autologging_client.flush(synchronous=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     532         original_result = original(*_og_args, **_og_kwargs)
#     533         return original_result
# --> 535 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:470, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     461 try:
#     462     try_log_autologging_event(
#     463         AutologgingEventLogger.get_logger().log_original_function_start,
#     464         session,
#    (...)
#     468         og_kwargs,
#     469     )
# --> 470     original_fn_result = original_fn(*og_args, **og_kwargs)
#     472     try_log_autologging_event(
#     473         AutologgingEventLogger.get_logger().log_original_function_success,
#     474         session,
#    (...)
#     478         og_kwargs,
#     479     )
#     480     return original_fn_result
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:532, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     524 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     525 # during original function execution, even if silent mode is enabled
#     526 # (`silent=True`), since these warnings originate from the ML framework
#     527 # or one of its dependencies and are likely relevant to the caller
#     528 with set_non_mlflow_warnings_behavior_for_current_thread(
#     529     disable_warnings=False,
#     530     reroute_warnings=False,
#     531 ):
# --> 532     original_result = original(*_og_args, **_og_kwargs)
#     533     return original_result
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:184, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     181     elif class_weight == "balanced_subsample":
#     182         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 184     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185 else:
#     186     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:554, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     552     patch_function.call(call_original, *args, **kwargs)
#     553 else:
# --> 554     patch_function(call_original, *args, **kwargs)
#     556 session.state = "succeeded"
#     558 try_log_autologging_event(
#     559     AutologgingEventLogger.get_logger().log_patch_function_success,
#     560     session,
#    (...)
#     564     kwargs,
#     565 )
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:254, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     251     managed_run = create_managed_run()
#     253 try:
# --> 254     result = patch_function(original, *args, **kwargs)
#     255 except (Exception, KeyboardInterrupt):
#     256     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     257     # that runs are terminated if a user prematurely interrupts training execution
#     258     # (e.g. via sigint / ctrl-c)
#     259     if managed_run:
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/sklearn/__init__.py:1587, in _autolog.<locals>.patched_fit(fit_impl, allow_children_patch, original, self, *args, **kwargs)
#    1585     return result
#    1586 else:
# -> 1587     return original(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     532         original_result = original(*_og_args, **_og_kwargs)
#     533         return original_result
# --> 535 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:470, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     461 try:
#     462     try_log_autologging_event(
#     463         AutologgingEventLogger.get_logger().log_original_function_start,
#     464         session,
#    (...)
#     468         og_kwargs,
#     469     )
# --> 470     original_fn_result = original_fn(*og_args, **og_kwargs)
#     472     try_log_autologging_event(
#     473         AutologgingEventLogger.get_logger().log_original_function_success,
#     474         session,
#    (...)
#     478         og_kwargs,
#     479     )
#     480     return original_fn_result
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/utils/autologging_utils/safety.py:532, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     524 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     525 # during original function execution, even if silent mode is enabled
#     526 # (`silent=True`), since these warnings originate from the ML framework
#     527 # or one of its dependencies and are likely relevant to the caller
#     528 with set_non_mlflow_warnings_behavior_for_current_thread(
#     529     disable_warnings=False,
#     530     reroute_warnings=False,
#     531 ):
# --> 532     original_result = original(*_og_args, **_og_kwargs)
#     533     return original_result
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=10,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=20,
    trials=Trials()
)
# Out:
# [20:53:57] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:10.16913
# [1]	validation-rmse:7.36294
# [2]	validation-rmse:6.72951
# [3]	validation-rmse:6.57960
# [4]	validation-rmse:6.51276
# [5]	validation-rmse:6.48991
# [6]	validation-rmse:6.47815
# [7]	validation-rmse:6.47018
# [8]	validation-rmse:6.46347
# [9]	validation-rmse:6.45846
# [20:54:03] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.38525
# [1]	validation-rmse:11.75647
# [2]	validation-rmse:9.57854
# [3]	validation-rmse:8.31310
# [4]	validation-rmse:7.60547
# [5]	validation-rmse:7.21254
# [6]	validation-rmse:6.99227
# [7]	validation-rmse:6.86395
# [8]	validation-rmse:6.78682
# [9]	validation-rmse:6.73896
# [20:54:05] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.96802
# [1]	validation-rmse:11.25616
# [2]	validation-rmse:9.14221
# [3]	validation-rmse:7.99912
# [4]	validation-rmse:7.39740
# [5]	validation-rmse:7.07824
# [6]	validation-rmse:6.89998
# [7]	validation-rmse:6.79865
# [8]	validation-rmse:6.73948
# [9]	validation-rmse:6.70237
# [20:54:08] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.90466
# [1]	validation-rmse:16.93878
# [2]	validation-rmse:15.25580
# [3]	validation-rmse:13.82145
# [4]	validation-rmse:12.60235
# [5]	validation-rmse:11.57679
# [6]	validation-rmse:10.71233
# [7]	validation-rmse:9.98694
# [8]	validation-rmse:9.38535
# [9]	validation-rmse:8.88579
# [20:54:16] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.67953
# [1]	validation-rmse:16.56470
# [2]	validation-rmse:14.78641
# [3]	validation-rmse:13.30030
# [4]	validation-rmse:12.06723
# [5]	validation-rmse:11.04802
# [6]	validation-rmse:10.20050
# [7]	validation-rmse:9.51630
# [8]	validation-rmse:8.95256
# [9]	validation-rmse:8.49758
# [20:54:28] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:10.35847
# [1]	validation-rmse:7.56568
# [2]	validation-rmse:6.93661
# [3]	validation-rmse:6.76873
# [4]	validation-rmse:6.71218
# [5]	validation-rmse:6.68698
# [6]	validation-rmse:6.67711
# [7]	validation-rmse:6.67333
# [8]	validation-rmse:6.66789
# [9]	validation-rmse:6.66251
# [20:54:31] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.86048
# [1]	validation-rmse:10.06186
# [2]	validation-rmse:8.23133
# [3]	validation-rmse:7.40009
# [4]	validation-rmse:7.02540
# [5]	validation-rmse:6.84857
# [6]	validation-rmse:6.75769
# [7]	validation-rmse:6.71006
# [8]	validation-rmse:6.68304
# [9]	validation-rmse:6.66730
# [20:54:33] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.23984
# [1]	validation-rmse:19.34243
# [2]	validation-rmse:18.49780
# [3]	validation-rmse:17.70204
# [4]	validation-rmse:16.95483
# [5]	validation-rmse:16.25174
# [6]	validation-rmse:15.59154
# [7]	validation-rmse:14.97278
# [8]	validation-rmse:14.39157
# [9]	validation-rmse:13.84693
# [20:54:41] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.54077
# [1]	validation-rmse:16.32921
# [2]	validation-rmse:14.50051
# [3]	validation-rmse:12.95732
# [4]	validation-rmse:11.71488
# [5]	validation-rmse:10.69513
# [6]	validation-rmse:9.86906
# [7]	validation-rmse:9.20171
# [8]	validation-rmse:8.67170
# [9]	validation-rmse:8.23912
# [20:54:55] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:7.76549
# [1]	validation-rmse:6.84607
# [2]	validation-rmse:6.73882
# [3]	validation-rmse:6.72194
# [4]	validation-rmse:6.71086
# [5]	validation-rmse:6.70846
# [6]	validation-rmse:6.70481
# [7]	validation-rmse:6.70335
# [8]	validation-rmse:6.70138
# [9]	validation-rmse:6.70176
# [20:54:59] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.67664
# [1]	validation-rmse:18.30144
# [2]	validation-rmse:17.05647
# [3]	validation-rmse:15.93091
# [4]	validation-rmse:14.91498
# [5]	validation-rmse:13.99921
# [6]	validation-rmse:13.17591
# [7]	validation-rmse:12.43674
# [8]	validation-rmse:11.77417
# [9]	validation-rmse:11.18260
# [20:55:01] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.62969
# [1]	validation-rmse:13.38538
# [2]	validation-rmse:11.12062
# [3]	validation-rmse:9.57881
# [4]	validation-rmse:8.54930
# [5]	validation-rmse:7.87781
# [6]	validation-rmse:7.44280
# [7]	validation-rmse:7.15511
# [8]	validation-rmse:6.96924
# [9]	validation-rmse:6.84514
# [20:55:06] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.63810
# [1]	validation-rmse:18.23356
# [2]	validation-rmse:16.97070
# [3]	validation-rmse:15.82780
# [4]	validation-rmse:14.79555
# [5]	validation-rmse:13.87725
# [6]	validation-rmse:13.04942
# [7]	validation-rmse:12.30566
# [8]	validation-rmse:11.64193
# [9]	validation-rmse:11.05336
# [20:55:18] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.48180
# [1]	validation-rmse:6.95063
# [2]	validation-rmse:6.73091
# [3]	validation-rmse:6.68799
# [4]	validation-rmse:6.67544
# [5]	validation-rmse:6.66801
# [6]	validation-rmse:6.65835
# [7]	validation-rmse:6.65338
# [8]	validation-rmse:6.65188
# [9]	validation-rmse:6.64779
# [20:55:20] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.36520
# [1]	validation-rmse:9.59133
# [2]	validation-rmse:7.92119
# [3]	validation-rmse:7.22524
# [4]	validation-rmse:6.92399
# [5]	validation-rmse:6.78794
# [6]	validation-rmse:6.71889
# [7]	validation-rmse:6.68336
# [8]	validation-rmse:6.66093
# [9]	validation-rmse:6.64649
# [20:55:25] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.86683
# [1]	validation-rmse:18.64943
# [2]	validation-rmse:17.53194
# [3]	validation-rmse:16.50879
# [4]	validation-rmse:15.57153
# [5]	validation-rmse:14.71645
# [6]	validation-rmse:13.93458
# [7]	validation-rmse:13.22168
# [8]	validation-rmse:12.57355
# [9]	validation-rmse:11.98422
# [20:55:26] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:7.38928
# [1]	validation-rmse:6.78593
# [2]	validation-rmse:6.74648
# [3]	validation-rmse:6.73413
# [4]	validation-rmse:6.70477
# [5]	validation-rmse:6.69773
# [6]	validation-rmse:6.69277
# [7]	validation-rmse:6.68410
# [8]	validation-rmse:6.67954
# [9]	validation-rmse:6.67201
# [20:55:27] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:10.64586
# [1]	validation-rmse:7.66172
# [2]	validation-rmse:6.90260
# [3]	validation-rmse:6.68266
# [4]	validation-rmse:6.60540
# [5]	validation-rmse:6.57951
# [6]	validation-rmse:6.56701
# [7]	validation-rmse:6.55547
# [8]	validation-rmse:6.55042
# [9]	validation-rmse:6.54684
# [20:55:35] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.93526
# [1]	validation-rmse:7.05357
# [2]	validation-rmse:6.76133
# [3]	validation-rmse:6.69930
# [4]	validation-rmse:6.67695
# [5]	validation-rmse:6.66186
# [6]	validation-rmse:6.64891
# [7]	validation-rmse:6.64484
# [8]	validation-rmse:6.63624
# [9]	validation-rmse:6.63611
# [20:55:40] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.44495
# [1]	validation-rmse:16.16825
# [2]	validation-rmse:14.29268
# [3]	validation-rmse:12.75508
# [4]	validation-rmse:11.50597
# [5]	validation-rmse:10.49749
# [6]	validation-rmse:9.69026
# [7]	validation-rmse:9.04385
# [8]	validation-rmse:8.53425
# [9]	validation-rmse:8.13426
# 100%|██████████| 20/20 [01:46<00:00,  5.30s/trial, best loss: 6.458455310990411]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")

        # mlflow.xgboost.autolog()
        params = {
            "learning_rate":	0.14080421574286942,
            "max_depth": 50,
            "min_child_weight":	1.721635493649425,
            "objective":	'reg:linear',
            "reg_alpha":	0.02681711890192135,
            "reg_lambda":	0.009206105899311917,
            "seed":	42
        }

        mlflow.log_params(params)

        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

        with open("models/preprocessor.b", "wb") as file:
            pickle.dump(dv, file)

        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [23:31:13] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.68552
# [1]	validation-rmse:16.56750
# [2]	validation-rmse:14.78471
# [3]	validation-rmse:13.29091
# [4]	validation-rmse:12.04843
# [5]	validation-rmse:11.01767
# [6]	validation-rmse:10.17235
# [7]	validation-rmse:9.47653
# [8]	validation-rmse:8.91244
# [9]	validation-rmse:8.45358
# [10]	validation-rmse:8.08293
# [11]	validation-rmse:7.78338
# [12]	validation-rmse:7.54389
# [13]	validation-rmse:7.35218
# [14]	validation-rmse:7.19659
# [15]	validation-rmse:7.07094
# [16]	validation-rmse:6.96973
# [17]	validation-rmse:6.88524
# [18]	validation-rmse:6.81683
# [19]	validation-rmse:6.76176
# [20]	validation-rmse:6.71628
# [21]	validation-rmse:6.67853
# [22]	validation-rmse:6.64571
# [23]	validation-rmse:6.61811
# [24]	validation-rmse:6.59465
# [25]	validation-rmse:6.57538
# [26]	validation-rmse:6.55821
# [27]	validation-rmse:6.54432
# [28]	validation-rmse:6.53186
# [29]	validation-rmse:6.52144
# [30]	validation-rmse:6.51413
# [31]	validation-rmse:6.50734
# [32]	validation-rmse:6.50147
# [33]	validation-rmse:6.49679
# [34]	validation-rmse:6.49178
# [35]	validation-rmse:6.48843
# [36]	validation-rmse:6.48499
# [37]	validation-rmse:6.48222
# [38]	validation-rmse:6.47936
# [39]	validation-rmse:6.47609
# [40]	validation-rmse:6.47412
# [41]	validation-rmse:6.47213
# [42]	validation-rmse:6.46993
# [43]	validation-rmse:6.46809
# [44]	validation-rmse:6.46654
# [45]	validation-rmse:6.46469
# [46]	validation-rmse:6.46256
# [47]	validation-rmse:6.46057
# [48]	validation-rmse:6.45831
# [49]	validation-rmse:6.45643
# [50]	validation-rmse:6.45433
# [51]	validation-rmse:6.45320
# [52]	validation-rmse:6.45198
# [53]	validation-rmse:6.45100
# [54]	validation-rmse:6.45036
# [55]	validation-rmse:6.44908
# [56]	validation-rmse:6.44745
# [57]	validation-rmse:6.44609
# [58]	validation-rmse:6.44562
# [59]	validation-rmse:6.44462
# [60]	validation-rmse:6.44346
# [61]	validation-rmse:6.44244
# [62]	validation-rmse:6.44190
# [63]	validation-rmse:6.44069
# [64]	validation-rmse:6.43987
# [65]	validation-rmse:6.43931
# [66]	validation-rmse:6.43854
# [67]	validation-rmse:6.43737
# [68]	validation-rmse:6.43655
# [69]	validation-rmse:6.43504
# [70]	validation-rmse:6.43357
# [71]	validation-rmse:6.43204
# [72]	validation-rmse:6.43106
# [73]	validation-rmse:6.42938
# [74]	validation-rmse:6.42856
# [75]	validation-rmse:6.42794
# [76]	validation-rmse:6.42726
# [77]	validation-rmse:6.42644
# [78]	validation-rmse:6.42581
# [79]	validation-rmse:6.42532
# [80]	validation-rmse:6.42465
# [81]	validation-rmse:6.42423
# [82]	validation-rmse:6.42362
# [83]	validation-rmse:6.42241
# [84]	validation-rmse:6.42200
# [85]	validation-rmse:6.42135
# [86]	validation-rmse:6.42085
# [87]	validation-rmse:6.42047
# [88]	validation-rmse:6.41977
# [89]	validation-rmse:6.41904
# [90]	validation-rmse:6.41840
# [91]	validation-rmse:6.41765
# [92]	validation-rmse:6.41689
# [93]	validation-rmse:6.41633
# [94]	validation-rmse:6.41596
# [95]	validation-rmse:6.41566
# [96]	validation-rmse:6.41496
# [97]	validation-rmse:6.41403
# [98]	validation-rmse:6.41344
# [99]	validation-rmse:6.41258

# %%
# with open('models/lr.bin', 'wb') as file:
#     pickle.dump((dv, lr), file)

# %%
# import mlflow
logged_model = 'runs:/f371a0c3fe2b48bf844a80dc2808f2ec/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# [23:33:29] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: f371a0c3fe2b48bf844a80dc2808f2ec

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
xgboost_model
# Out:
# [23:35:54] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgboost_model.predict(valid)
# Out:
# array([15.303841 ,  6.9746785, 17.123621 , ..., 13.363762 ,  6.2096205,
#         8.306488 ], dtype=float32)

# %%
loaded_model.predict(y_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 loaded_model.predict(y_val)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/pyfunc/__init__.py:427, in PyFuncModel.predict(self, data)
#     424         if _MLFLOW_OPENAI_TESTING.get():
#     425             raise
# --> 427 return self._predict_fn(data)
#
# File ~/anaconda3/lib/python3.10/site-packages/mlflow/xgboost/__init__.py:371, in _XGBModelWrapper.predict(self, dataframe)
#     368 import xgboost as xgb
#     370 if isinstance(self.xgb_model, xgb.Booster):
# --> 371     return self.xgb_model.predict(xgb.DMatrix(dataframe))
#     372 else:
#     373     return self.xgb_model.predict(dataframe)
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/data.py:952, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     950 '''Dispatch data for DMatrix.'''
#     951 if not _is_cudf_ser(data) and not _is_pandas_series(data):
# --> 952     _check_data_shape(data)
#     953 if _is_scipy_csr(data):
#     954     return _from_scipy_csr(data, missing, threads, feature_names, feature_types)
#
# File ~/anaconda3/lib/python3.10/site-packages/xgboost/data.py:62, in _check_data_shape(data)
#      60 def _check_data_shape(data: DataType) -> None:
#      61     if hasattr(data, "shape") and len(data.shape) != 2:
# ---> 62         raise ValueError("Please reshape the input data into 2-dimensional matrix.")
#
# ValueError: Please reshape the input data into 2-dimensional matrix.

# %%
# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))
